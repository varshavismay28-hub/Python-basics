# %% [markdown]
# <a href="https://colab.research.google.com/github/varshavismay28-hub/Python-basics/blob/main/Python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("HELLo WORLD")
# Out:
# HELLo WORLD

# %%
print ("varsha")
# Out:
# varsha

# %%
name="varsha"
year="2007"
print("Hello",name)
print(year)
# Out:
# Hello varsha
# 2007

# %%
name="vismay"
year="2009"
print (name+year)
# Out:
# vismay2009

# %%
a=4
b=2
print ("add",a+b)
print ("sub",a-b)
print ("multi",a*b)
print ("div",a/b)
# Out:
# add 6
# sub 2
# multi 8
# div 2.0

# %%
a=16
b=4
print ("div",a/b)
# Out:
# div 4.0

# %%
a=45
b=34
print("multi",a*b)
# Out:
# multi 1530

# %%
a=87
b=67
print ("sub",a-b)
# Out:
# sub 20

# %%
a=input("Enter your name")
b=input("Enter your branch")
print("Hi",a)
print("my branch is",b)
# Out:
# Enter your nameVarsha HR
# Enter your branchCSE
# Hi Varsha HR
# my branch is CSE

# %%
a=int(input("Enter your registr number"))
b=int(input("Enter your marks"))
print (a)
print (b)
print (a+b)
# Out:
# Enter your registr number50
# Enter your marks50
# 50
# 50
# 100

# %%
a=int(input("Enter your registr number"))
b=int(input("Enter your marks"))
print (a)
print (b)
print (a/b)
# Out:
# Enter your registr number45
# Enter your marks5
# 45
# 5
# 9.0

# %%
a=int(input("Enter your registr number"))
b=int(input("Enter your marks"))
print (a)
print (b)
print (a-b)
# Out:
# Enter your registr number25
# Enter your marks5
# 25
# 5
# 20

# %%
a=int(input("Enter your registr number"))
b=int(input("Enter your marks"))
print (a)
print (b)
print (a*b)
# Out:
# Enter your registr number13
# Enter your marks13
# 13
# 13
# 169

# %%
age=int(input("Enter your age"))
if age>=18:

   print ("you can vote")

else:

   print ("come agin next year")
# Out:
# Enter your age18
# you can vote
