# %% [markdown]
# <a href="https://colab.research.google.com/github/varshavismay28-hub/Python-basics/blob/main/Python__basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("varsha")
# Out:
# varsha
